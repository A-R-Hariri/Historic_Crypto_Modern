# %%
from LiveCryptoData import LiveCryptoData

new = LiveCryptoData('ATOM-USD').return_data()
new
# Out:
# Checking inputs...
# Collecting data for 'BTC-USD'
# Checking if user supplied is available on the CoinBase Pro API...
# Connected to the CoinBase Pro API.
# Ticker 'BTC-USD' found at the CoinBase Pro API, continuing to extraction.
# Status Code: 200, successful API call.
#                                           ask       bid         volume  \
# time
# 2026-01-02 15:18:00.937093458+00:00  89077.35  89072.03  6457.17035916
#
#                                       trade_id     price        size  \
# time
# 2026-01-02 15:18:00.937093458+00:00  930281660  89072.01  0.00022457
#
#                                     rfq_volume
# time
# 2026-01-02 15:18:00.937093458+00:00  58.513538
# Checking inputs...
# Collecting data for 'ATOM-USD'
# Checking if user supplied is available on the CoinBase Pro API...
# Connected to the CoinBase Pro API.
# Ticker 'ATOM-USD' found at the CoinBase Pro API, continuing to extraction.
# Status Code: 200, successful API call.
#                                        ask    bid     volume  trade_id  price  \
# time
# 2026-01-02 15:17:54.154505162+00:00  2.117  2.116  630234.03  61118119  2.118
#
#                                     size     rfq_volume
# time
# 2026-01-02 15:17:54.154505162+00:00  1.1  150628.365774

# %%
from HistoricalData import HistoricalData

new = HistoricalData('ETH-USD', 300, '2025-06-01-00-00', '2025-06-02-00-00').retrieve_data()
new.head()
# Out:
# Checking input parameters are in the correct format.
# Formatting Dates.
# Checking if user supplied is available on the CoinBase Pro API.
# Connected to the CoinBase Pro API.
# Ticker 'BTC-USD' found at the CoinBase Pro API, continuing to extraction.
# Provisional Start: 2021-06-01T00:00:00
# Provisional End: 2021-06-13T12:00:00
# Data for chunk 1 of 3 extracted
# Provisional Start: 2021-06-13T12:00:00
# Provisional End: 2021-06-26T00:00:00
# Data for chunk 2 of 3 extracted
# Provisional Start: 2021-06-26T00:00:00
# Provisional End: 2021-07-08T12:00:00
# Data for chunk 3 of 3 extracted
#                           low      high      open     close       volume
# time
# 2021-06-01 00:00:00  37140.92  37918.97  37276.23  37849.85  1382.050493
# 2021-06-01 01:00:00  37170.07  37831.06  37831.06  37200.52   632.492777
# 2021-06-01 02:00:00  36636.47  37300.00  37200.52  36860.57   647.014915
# 2021-06-01 03:00:00  36500.00  37139.33  36856.82  36714.69   555.584683
# 2021-06-01 04:00:00  36572.97  36956.48  36714.69  36753.45   331.339400
#                           low      high      open     close       volume
# time
# 2021-06-30 20:00:00  34382.40  35111.97  34763.47  34586.79  1139.204560
# 2021-06-30 21:00:00  34584.87  35030.76  34587.08  34822.21   462.919944
# 2021-06-30 22:00:00  34631.12  34940.13  34822.53  34904.72   279.278281
# 2021-06-30 23:00:00  34907.98  35219.14  34907.98  35060.00   480.176725
# 2021-07-01 00:00:00  34700.12  35066.54  35060.00  34731.08   692.055653
# Checking input parameters are in the correct format.
# Formatting Dates.
# Checking if user supplied is available on the CoinBase Pro API.
# Connected to the CoinBase Pro API.
# Ticker 'ETH-USD' found at the CoinBase Pro API, continuing to extraction.
# Retrieved Data from Coinbase Pro API.
# Returning data.
#                          low     high     open    close      volume
# time
# 2025-06-01 00:00:00  2525.14  2530.05  2529.31  2525.70  252.806901
# 2025-06-01 00:05:00  2525.65  2529.00  2526.02  2528.34  111.648355
# 2025-06-01 00:10:00  2519.47  2528.63  2528.35  2521.33  404.895317
# 2025-06-01 00:15:00  2517.44  2522.03  2521.59  2521.46  312.173969
# 2025-06-01 00:20:00  2518.33  2524.18  2521.29  2522.62  236.766209

# %%
from HistoricalData import HistoricalData

new = HistoricalData('ETH-USD', '1d', '2025-06-01-00-00', '2025-06-30-00-00').retrieve_data()
new.head()
# Out:
# Checking input parameters are in the correct format.
# Formatting Dates.
# Checking if user supplied is available on the CoinBase Pro API.
# Connected to the CoinBase Pro API.
# Ticker 'BTC-USD' found at the CoinBase Pro API, continuing to extraction.
# Provisional Start: 2021-06-01T00:00:00
# Provisional End: 2021-06-13T12:00:00
# Data for chunk 1 of 3 extracted
# Provisional Start: 2021-06-13T12:00:00
# Provisional End: 2021-06-26T00:00:00
# Data for chunk 2 of 3 extracted
# Provisional Start: 2021-06-26T00:00:00
# Provisional End: 2021-07-08T12:00:00
# Data for chunk 3 of 3 extracted
#                           low      high      open     close       volume
# time
# 2021-06-01 00:00:00  37140.92  37918.97  37276.23  37849.85  1382.050493
# 2021-06-01 01:00:00  37170.07  37831.06  37831.06  37200.52   632.492777
# 2021-06-01 02:00:00  36636.47  37300.00  37200.52  36860.57   647.014915
# 2021-06-01 03:00:00  36500.00  37139.33  36856.82  36714.69   555.584683
# 2021-06-01 04:00:00  36572.97  36956.48  36714.69  36753.45   331.339400
#                           low      high      open     close       volume
# time
# 2021-06-30 20:00:00  34382.40  35111.97  34763.47  34586.79  1139.204560
# 2021-06-30 21:00:00  34584.87  35030.76  34587.08  34822.21   462.919944
# 2021-06-30 22:00:00  34631.12  34940.13  34822.53  34904.72   279.278281
# 2021-06-30 23:00:00  34907.98  35219.14  34907.98  35060.00   480.176725
# 2021-07-01 00:00:00  34700.12  35066.54  35060.00  34731.08   692.055653
# Checking input parameters are in the correct format.
# Formatting Dates.
# Checking if user supplied is available on the CoinBase Pro API.
# Connected to the CoinBase Pro API.
# Ticker 'ETH-USD' found at the CoinBase Pro API, continuing to extraction.
# Retrieved Data from Coinbase Pro API.
# Returning data.
#                 low     high     open    close         volume
# time
# 2025-06-01  2470.50  2550.00  2529.31  2540.38   53153.067124
# 2025-06-02  2476.13  2616.87  2540.40  2609.29  127353.973355
# 2025-06-03  2575.75  2657.74  2609.29  2595.03  175792.326876
# 2025-06-04  2584.05  2681.00  2595.03  2609.07  105615.844918
# 2025-06-05  2392.16  2642.53  2609.19  2415.34  205698.418658

# %%
from Cryptocurrencies import Cryptocurrencies

data = Cryptocurrencies(coin_search = 'XLM', extended_output=False).find_crypto_pairs()
data
# Out:
# Connected to the CoinBase Pro API.
# Found 5 instances containing the term DOGE.
# Extended Output is False, returning reduced dataset.
#             id display_name  fx_stablecoin max_slippage_percentage  status
# 171   DOGE-USD     DOGE-USD          False              0.03000000  online
# 175   DOGE-BTC     DOGE-BTC          False              0.03000000  online
# 235   DOGE-EUR     DOGE-EUR          False              0.03000000  online
# 579  DOGE-USDT    DOGE-USDT          False              0.03000000  online
# 746   DOGE-GBP     DOGE-GBP          False              0.03000000  online
# Connected to the CoinBase Pro API.
# Found 4 instances containing the term XLM.
# Extended Output is False, returning reduced dataset.
#            id display_name  fx_stablecoin max_slippage_percentage  status
# 166   XLM-EUR      XLM-EUR          False              0.03000000  online
# 232   XLM-BTC      XLM-BTC          False              0.03000000  online
# 252  XLM-USDT     XLM-USDT          False              0.03000000  online
# 678   XLM-USD      XLM-USD          False              0.03000000  online
